# %%
import psycopg2
import pandas as pd

# %%
connection_args = {
    'host': 'localhost',
    'dbname': 'eol',
    'port': 5432,
    'user': 'postgres',
    'password': 1234
}

try:
    connection = psycopg2.connect(**connection_args)

    cursor = connection.cursor()
    # Print PostgreSQL Connection properties
    print ( connection.get_dsn_parameters(),"\n")

    # Print PostgreSQL version
    #cursor.execute("SELECT page_id, COUNT(1) AS num from all_pantheria GROUP BY page_id ORDER BY num desc LIMIT 100;")
    cursor.execute("SELECT * from all_features;")
    #cursor.execute("SELECT * from all_pantheria WHERE page_id=47049861 LIMIT 100;")
    df = pd.DataFrame(cursor.fetchall(), columns=[c[0] for c in cursor.description])
    
    
except (Exception, psycopg2.Error) as error :
    print ("Error while connecting to PostgreSQL", error)
finally:
    #closing database connection.
        if(connection):
            cursor.close()
            connection.close()
            print("PostgreSQL connection is closed")
df
# Out:
# {'user': 'postgres', 'dbname': 'eol', 'host': 'localhost', 'port': '5432', 'tty': '', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'gssencmode': 'prefer', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# PostgreSQL connection is closed
#        page_id conservation_status              habitat trophic_level  \
# 0       115643       least concern  terrestrial habitat          None
# 1       115670     near threatened  terrestrial habitat          None
# 2       115718     near threatened  terrestrial habitat          None
# 3       115738       least concern  terrestrial habitat     herbivore
# 4       115784       least concern  terrestrial habitat     carnivore
# ...        ...                 ...                  ...           ...
# 4618  51906708          endangered  terrestrial habitat          None
# 4619  51906710       least concern  terrestrial habitat          None
# 4620  51906731          endangered  terrestrial habitat          None
# 4621  51906742      data deficient  terrestrial habitat          None
# 4622  51906785       least concern  terrestrial habitat      omnivore
#
#       body_mass body_mass_units  pop_density  \
# 0           NaN            None       135.76
# 1           NaN            None        52.56
# 2           NaN            None        14.00
# 3       1355.23               g        79.55
# 4          4.20               g        16.94
# ...         ...             ...          ...
# 4618     149.63               g          NaN
# 4619        NaN            None       155.18
# 4620     419.99               g        13.00
# 4621      60.17               g          NaN
# 4622      17.02               g        12.00
#
#                      pop_density_units    geog_range geog_range_units
# 0     individuals per square kilometer  1.926860e+11              m^2
# 1     individuals per square kilometer  1.268012e+11              m^2
# 2     individuals per square kilometer  8.265000e+07              m^2
# 3     individuals per square kilometer  3.600388e+11              m^2
# 4     individuals per square kilometer  1.056725e+13              m^2
# ...                                ...           ...              ...
# 4618                              None           NaN             None
# 4619  individuals per square kilometer  5.545095e+11              m^2
# 4620  individuals per square kilometer  5.496090e+09              m^2
# 4621                              None           NaN             None
# 4622  individuals per square kilometer  1.821448e+12              m^2
#
# [4623 rows x 10 columns]
